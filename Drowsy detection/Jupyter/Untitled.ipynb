# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
pip install torch torchvision torchaudio
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\pero_student01\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
cd yolov5
# Out:
# C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter\yolov5

# %%
pip install -r requirements.txt
# Out:
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.1
#     Uninstalling setuptools-49.2.1:
#       Successfully uninstalled setuptools-49.2.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\pero_student01\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import torch 
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\pero_student01/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-3-25 Python-3.9.0 torch-2.0.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 48, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
cap = cv2.VideoCapture(1)
while cap.isOpened():
    ret,frame = cap.read()
    
    results = model(frame)
    
    cv2.imshow('test',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Requirement already up-to-date: pyqt5 in c:\users\pero_student01\appdata\local\programs\python\python39\lib\site-packages (5.15.9)
# Requirement already up-to-date: lxml in c:\users\pero_student01\appdata\local\programs\python\python39\lib\site-packages (4.9.2)
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\pero_student01\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# The system cannot find the path specified.

# %%
import uuid
import os
import time

# %%
# !cd Jupyter
# Out:
# The system cannot find the path specified.

# %%
# !cd
# Out:
# C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter

# %%
IMAGE_PATH = os.path.join('data','images')
labels = ['awake','drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(4)
    for img_num in range(number_imgs):
        print('Collecting images for {},image number {}'.format(label, img_num))
        
        ret, frame = cap.read()
        imgname = os.path.join(IMAGE_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname, frame)
        cv2.imshow('Image Collection', frame)
        time.sleep(2)
        
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
cd C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter
# Out:
# C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter

# %%
cd C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter\yolov5
# Out:
# C:\Users\pero_student01\Documents\GitHub\ScaredToCompile_Porsche_Engineering_Student_Contest\Drowsy detection\Jupyter

# %%
python train.py --img 320 --batch 16 --epochs 100 --data dataset.yaml --weights yolov5s.pt
# Out:
#   Cell In[5], line 1
#     python train.py --img 320 --batch 16 --epochs 100 --data dataset.yaml --weights yolov5s.pt
#            ^
# SyntaxError: invalid syntax

# %%
model = torch.hub.load('yolov5','custom',path='yolov5/runs/train/exp14/weights/best.pt', source = 'local', force_reload=True)
# Out:
# YOLOv5  2023-3-25 Python-3.9.0 torch-2.0.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame = cap.read()
    
    results = model(frame)
    
    cv2.imshow('test',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
img = os.path.join('data','images','00001_00003_00001.png')

# %%
results = model(img)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# !pip install onnxruntime
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\pero_student01\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import io
import numpy as np

from torch import nn
import torch.utils.model_zoo as model_zoo
import torch.onnx

# %%
# Input to the model
x = torch.randn(batch_size, 1, 224, 224, requires_grad=True)
torch_out = torch_model(x)

# Export the model
torch.onnx.export(torch_model,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "super_resolution.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}})
